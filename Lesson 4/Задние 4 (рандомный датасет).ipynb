# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
import pandas as pd
plt.style.use('fivethirtyeight')

# %%
salary = pd.read_csv('ds_salaries.csv')

# %%
df = pd.read_csv('ds_salaries.csv')

# %%
class_list = salary['salary'].value_counts()
print(class_list)
# Out:
# 100000     18
# 80000      18
# 120000     15
# 60000      15
# 150000     14
#            ..
# 256000      1
# 39600       1
# 1335000     1
# 52500       1
# 129000      1
# Name: salary, Length: 272, dtype: int64

# %%
class_list.plot(kind='barh')
plt.show()

# %%
class_list.plot(kind='barh', logx=True)
plt.show()
